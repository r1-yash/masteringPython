# %%
class Error(Exception):
    pass

class dobException(Error):
    pass

# %%
year = int(input("Enter your dob"))
age = 2026-year

try:
    if age>=20 and age <=30:
            print("You can login")
    else:
            raise dobException
except dobException:
       print("You can't")
# Out:
# You can login
