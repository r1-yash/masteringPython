# %% [markdown]
# Classes and Objects - page number 4
#
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.

# %%
### A class is a blue print for creating objects. Attributes,methods
class Car:
    pass

audi=Car()
bmw=Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
audi.windows=4

print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.doors=4
print(tata.windows)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 tata=Car()
#       2 tata.doors=4
# ----> 3 print(tata.windows)
#
# AttributeError: 'Car' object has no attribute 'windows'

# %% [markdown]
# so we now see that we need to declare the variables at one place, isntance variables

# %%
### Instance Variable and Methods
class Dog:
    ## constructor
    def __init__(self,name,age):
        self.name=name
        self.age=age

## create objects
dog1=Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2=Dog("Lucy",4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
## Define a class with instance methods
class Dog:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    
    def bark(self):
        print(f"{self.name} says woof")


dog1=Dog("Buddy",3)
dog1.bark()
dog2=Dog("Lucy",4)
dog2.bark()
# Out:
# Buddy says woof
# Lucy says woof

# %%
#modeling a bank account

class BankAccount:

    def __init__(self, owner, amount):
        self.owner=owner
        self.amount=amount

    def addMoney(self, deposit):
        self.amount+=deposit
        print(f"{self.amount} is the new amount you have in bank")

    def withDraw(self, take):
        if(take > self.amount):
            print("Not enough money")
        else:
            self.amount -= take
            print(f"{self.amount} is the new Balance")

    def checkBalance(self):
        print(f"You have {self.amount} in your account")

# %%
account = BankAccount("Yash", 5000)

# %%
account.withDraw(500)
# Out:
# 4500 is the new Balance

# %%
account.addMoney(5000)
# Out:
# 9500 is the new amount you have in bank

# %%
account.checkBalance()
# Out:
# You have 9500 in your account
