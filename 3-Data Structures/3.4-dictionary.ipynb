# %%
#Dictionaries are unordered collections of items. They store data in key-value pairs. Keys must be unique and immutable (e.g., strings, numbers, or tuples), while values can be of any type.

# %%
# Single key is slways used
student={"name":"Krish","age":32,"name":24}
print(student)
# Out:
# {'name': 24, 'age': 32}

# %%
student={"name":"Krish","age":32,"grade":'A'}

# %%
## Accessing Dictionary elements
print(student['grade'])
print(student['age'])

## Accessing using get() method
print(student.get('grade'))
print(student.get('last_name'))
print(student.get('last_name',"Not Available"))
# Out:
# A
# 32
# A
# None
# Not Available

# %%
student["age"]=33  ##update value for the key
print(student)
student["address"]="India" ## added a new key and value
print(student)
# Out:
# {'name': 'Krish', 'age': 33, 'grade': 'A'}
# {'name': 'Krish', 'age': 33, 'grade': 'A', 'address': 'India'}

# %%
del student['grade'] ## delete key and value pair

print(student)
# Out:
# {'name': 'Krish', 'age': 33, 'address': 'India'}

# %%
## Dictionary methods

keys=student.keys() ##get all the keys
print(keys)
values=student.values() ##get all values
print(values)

items=student.items() ##get all key value pairs
print(items)
# Out:
# dict_keys(['name', 'age', 'address'])
# dict_values(['Krish', 33, 'India'])
# dict_items([('name', 'Krish'), ('age', 33), ('address', 'India')])

# %%
## shallow copy
student_copy=student
print(student)
print(student_copy)
# Out:
# {'name': 'Krish', 'age': 33, 'address': 'India'}
# {'name': 'Krish', 'age': 33, 'address': 'India'}

# %%
student["name"]="Krish2"
print(student)
print(student_copy)
# Out:
# {'name': 'Krish2', 'age': 33, 'address': 'India'}
# {'name': 'Krish2', 'age': 33, 'address': 'India'}

# %%
student_copy1=student.copy() ## shallow copy
print(student_copy1)
print(student)
# what shallow copy does is allocates a different memory 
# meaning no change to copy shit even if original is modified
# Out:
# {'name': 'KRish3', 'age': 33, 'address': 'India'}
# {'name': 'KRish3', 'age': 33, 'address': 'India'}

# %%
student["name"]="KRish3"
print(student_copy1)
print(student)
# Out:
# {'name': 'KRish3', 'age': 33, 'address': 'India'}
# {'name': 'KRish3', 'age': 33, 'address': 'India'}

# %%
### Iterating Over Dictionaries
## You can use loops to iterate over dictionatries, keys,values,or items

## Iterating over keys
for keys in student.keys():
    print(keys)
# Out:
# name
# age
# address

# %%
## Iterate over values
for value in student.values():
    print(value)
# Out:
# KRish3
# 33
# India

# %%
## Iterate over key value pairs
for key,value in student.items():
    print(f"{key}:{value}")
# Out:
# name:KRish3
# age:33
# address:India

# %%
## Nested Disctionaries
students={
    "student1":{"name":"Krish","age":32},
    "student2":{"name":"Peter","age":35}
}
print(students)
# Out:
# {'student1': {'name': 'Krish', 'age': 32}, 'student2': {'name': 'Peter', 'age': 35}}

# %%
print(students["student1"]["name"])
print(students.items())
# Out:
# Krish
# dict_items([('student1', {'name': 'Krish', 'age': 32}), ('student2', {'name': 'Peter', 'age': 35})])

# %%
#have to put .items while iterating in an dictionary
for s_id, s_info in students.items():
    for s_name, s_age in s_info.items():
        print(f"{s_name} : {s_age}")
# Out:
# name : Krish
# age : 32
# name : Peter
# age : 35

# %%
sqr = {x:x**2 for x in range(0,6)}
sqr
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
## Practical Examples

## USe a dictionary to count he frequency of elements in list

numbers=[1,2,2,3,3,3,4,4,4,4]
freq = {}

for i in numbers:
    if i in freq:
        freq[i]+=1
    else:
        freq[i]=1
freq
# Out:
# {1: 1, 2: 2, 3: 3, 4: 4}

# %%
## Merge 2 dictionaries into one

dict1={"a":1,"b":2}
dict2={"b":3,"c":4}
merged_dict={**dict1,**dict2}
print(merged_dict)
# Out:
# {'a': 1, 'b': 3, 'c': 4}
