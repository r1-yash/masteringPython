# %%
#pos neg or zero 
a = int(input("Enter"))

if a>0:
    print("greater than 0")
elif a<0:
    print("less")
else:
    print("zero")
# Out:
# greater than 0

# %%
#swap two vars
a = 5
b= 7

c=a
a=b
b=c

print(a,b)
# Out:
# 7 5

# %%
string1 = "Hello"
string2 = "World"
print(string1 + " " + string2)
# Out:
# Hello World

# %%
a = "hi"

if type(a) == str:
    print("True")
else:
    print("False")
# Out:
# True

# %%
a=5
print(a**2)
# Out:
# 25

# %%
a=7
if(a%2==0):
    print("even")
else:
    print("odd")
# Out:
# odd
