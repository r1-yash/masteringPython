# %%
ans = "hello" + str(5)
print(ans)
# Out:
# hello5

# %%
ans = str(hellooo)
print(ans)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 ans = str(hellooo)
#       2 print(ans)
#
# NameError: name 'hellooo' is not defined
